# %% [markdown]
# Omar Pineda Jr.
# DATA612: Recommender Systems, Summer 2020
# CUNY SPS MS Data Science
# Project 1: Simple Recommender System for Amazon Healthcare Products

# %%
import pandas as pd
from numpy import nan
import random
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# This simple recommender system will predict how a user would rate a healthcare product based on how they rated other healthcare products. These predicted ratings can be used to suggest new items that a user would probably enjoy and from a seller's perspective buy. We sourced this data from Amazon's product reviews between May 1996 - July 2014: http://jmcauley.ucsd.edu/data/amazon/links.html

# %% [markdown]
# First, we load our dataset of 2.9 million reviews and add column names. The users are identified by unique reviewer IDs and the products are coded with Amazon Standard Identification Numbers (ASINs).

# %%
hc = pd.read_csv('ratings_Health_and_Personal_Care.csv', header = None)
hc.head()

# %%
hc.shape
# Out:
# (2982326, 3)

# %%
hc.columns = ['user', 'product', 'rating', 'time']
hc = hc.drop(columns='time')
hc.head()
# Out:
#              user     product  rating
# 0   ARMDSTEI0Z7YW  0077614992     5.0
# 1   A3FYN0SZYWN74  0615208479     5.0
# 2  A2J0WRZSAAHUAP  0615269990     5.0
# 3  A38RKP6G5P8J63  0615269990     5.0
# 4   ARENM677YXZKX  0615269990     2.0

# %% [markdown]
# We then reformatted our dataframe to make it wide rather than long, with a row for each reviewer and a column for each product, producing a user-item matrix. In order to keep things simple for this project, we only looked at the first 25 entries in the dataset, but that unfortunately limited our scope so that each reviewer only had a review for a single product.

# %%
hc2 = hc.head(25)
hc3 = hc2.pivot(index = 'user', columns = 'product', values = 'rating')
hc3
# Out:
# product         0077614992  0615208479  0615269990  0615315860  0615406394  \
# user
# A102TGNH1D915Z         NaN         NaN         NaN         NaN         NaN
# A11O3IHGGJBH67         NaN         NaN         NaN         NaN         NaN
# A12V35OD8T4ZVP         NaN         NaN         NaN         NaN         5.0
# A1LBXMFXPT2F7Q         NaN         NaN         NaN         NaN         NaN
# A1P27BGF8NAI29         NaN         NaN         NaN         NaN         NaN
# A2BWNU3Z38JEZ7         NaN         NaN         NaN         NaN         NaN
# A2COS3K6OVGHO8         NaN         NaN         NaN         NaN         5.0
# A2J0WRZSAAHUAP         NaN         NaN         5.0         NaN         NaN
# A2KX3GMQY9LS9N         NaN         NaN         NaN         5.0         NaN
# A2RGVNP1D6LRTA         NaN         NaN         NaN         NaN         NaN
# A30CP7L9JPBWX          NaN         NaN         NaN         NaN         NaN
# A34IX57PYIKFFF         NaN         NaN         NaN         NaN         NaN
# A35G5VLYZIDBAU         NaN         NaN         NaN         NaN         5.0
# A361YMXSRYL4K4         NaN         NaN         NaN         NaN         NaN
# A36IT4R58E2F10         NaN         NaN         NaN         NaN         4.0
# A38RKP6G5P8J63         NaN         NaN         5.0         NaN         NaN
# A3FYN0SZYWN74          NaN         5.0         NaN         NaN         NaN
# A3NNL2LPM66ZH5         NaN         NaN         NaN         NaN         NaN
# A42VPA76SE1U3          NaN         NaN         NaN         NaN         NaN
# AJCPRB73A2EPV          NaN         NaN         NaN         NaN         NaN
# AMBJQQSRCAOHS          NaN         NaN         NaN         5.0         NaN
# ANLSE84SL6HWI          NaN         NaN         NaN         NaN         NaN
# ARENM677YXZKX          NaN         NaN         2.0         NaN         NaN
# ARMDSTEI0Z7YW          5.0         NaN         NaN         NaN         NaN
# AVFXCA5AW8I7F          NaN         NaN         NaN         NaN         5.0
#
# product         0615836828  0641710577  0641864507  0681504498  0705394638
# user
# A102TGNH1D915Z         NaN         NaN         NaN         3.0         NaN
# A11O3IHGGJBH67         NaN         NaN         5.0         NaN         NaN
# A12V35OD8T4ZVP         NaN         NaN         NaN         NaN         NaN
# A1LBXMFXPT2F7Q         NaN         NaN         NaN         1.0         NaN
# A1P27BGF8NAI29         NaN         NaN         NaN         NaN         5.0
# A2BWNU3Z38JEZ7         NaN         5.0         NaN         NaN         NaN
# A2COS3K6OVGHO8         NaN         NaN         NaN         NaN         NaN
# A2J0WRZSAAHUAP         NaN         NaN         NaN         NaN         NaN
# A2KX3GMQY9LS9N         NaN         NaN         NaN         NaN         NaN
# A2RGVNP1D6LRTA         NaN         NaN         NaN         5.0         NaN
# A30CP7L9JPBWX          NaN         NaN         NaN         4.0         NaN
# A34IX57PYIKFFF         NaN         NaN         NaN         1.0         NaN
# A35G5VLYZIDBAU         NaN         NaN         NaN         NaN         NaN
# A361YMXSRYL4K4         5.0         NaN         NaN         NaN         NaN
# A36IT4R58E2F10         NaN         NaN         NaN         NaN         NaN
# A38RKP6G5P8J63         NaN         NaN         NaN         NaN         NaN
# A3FYN0SZYWN74          NaN         NaN         NaN         NaN         NaN
# A3NNL2LPM66ZH5         5.0         NaN         NaN         NaN         NaN
# A42VPA76SE1U3          NaN         NaN         NaN         1.0         NaN
# AJCPRB73A2EPV          5.0         NaN         NaN         NaN         NaN
# AMBJQQSRCAOHS          NaN         NaN         NaN         NaN         NaN
# ANLSE84SL6HWI          NaN         NaN         NaN         2.0         NaN
# ARENM677YXZKX          NaN         NaN         NaN         NaN         NaN
# ARMDSTEI0Z7YW          NaN         NaN         NaN         NaN         NaN
# AVFXCA5AW8I7F          NaN         NaN         NaN         NaN         NaN

# %% [markdown]
# Instead, we recreated our table with dummy ratings from 1-5 so that a buyer would have reviews for multiple products. We also included some NAs in our matrix. We will hopefully use the original complete dataset in a future project.

# %%
random_ratings = [1,2,3,4,5,nan]
hc4 = hc3.copy()
for i in hc4.columns.values:
    for j in hc4.index.values:
        hc4[i][j] = random.choice(random_ratings)
hc4
# Out:
# product         0077614992  0615208479  0615269990  0615315860  0615406394  \
# user
# A102TGNH1D915Z         2.0         3.0         4.0         5.0         NaN
# A11O3IHGGJBH67         5.0         4.0         1.0         2.0         5.0
# A12V35OD8T4ZVP         2.0         2.0         NaN         3.0         1.0
# A1LBXMFXPT2F7Q         NaN         NaN         3.0         NaN         NaN
# A1P27BGF8NAI29         NaN         3.0         5.0         4.0         1.0
# A2BWNU3Z38JEZ7         2.0         5.0         5.0         2.0         4.0
# A2COS3K6OVGHO8         NaN         2.0         NaN         5.0         2.0
# A2J0WRZSAAHUAP         2.0         NaN         NaN         NaN         3.0
# A2KX3GMQY9LS9N         1.0         5.0         2.0         2.0         3.0
# A2RGVNP1D6LRTA         3.0         2.0         4.0         5.0         2.0
# A30CP7L9JPBWX          5.0         5.0         5.0         4.0         NaN
# A34IX57PYIKFFF         NaN         4.0         1.0         3.0         3.0
# A35G5VLYZIDBAU         2.0         3.0         3.0         NaN         2.0
# A361YMXSRYL4K4         3.0         4.0         1.0         4.0         NaN
# A36IT4R58E2F10         3.0         2.0         2.0         1.0         NaN
# A38RKP6G5P8J63         2.0         3.0         5.0         5.0         2.0
# A3FYN0SZYWN74          4.0         3.0         4.0         3.0         NaN
# A3NNL2LPM66ZH5         1.0         5.0         NaN         NaN         5.0
# A42VPA76SE1U3          NaN         1.0         NaN         1.0         5.0
# AJCPRB73A2EPV          NaN         1.0         1.0         3.0         NaN
# AMBJQQSRCAOHS          NaN         5.0         5.0         4.0         4.0
# ANLSE84SL6HWI          5.0         3.0         4.0         4.0         4.0
# ARENM677YXZKX          NaN         1.0         NaN         NaN         3.0
# ARMDSTEI0Z7YW          NaN         3.0         1.0         1.0         4.0
# AVFXCA5AW8I7F          5.0         2.0         5.0         2.0         NaN
#
# product         0615836828  0641710577  0641864507  0681504498  0705394638
# user
# A102TGNH1D915Z         5.0         4.0         3.0         NaN         3.0
# A11O3IHGGJBH67         3.0         4.0         4.0         2.0         1.0
# A12V35OD8T4ZVP         4.0         NaN         4.0         1.0         1.0
# A1LBXMFXPT2F7Q         5.0         1.0         4.0         3.0         3.0
# A1P27BGF8NAI29         2.0         5.0         5.0         5.0         4.0
# A2BWNU3Z38JEZ7         3.0         3.0         3.0         5.0         NaN
# A2COS3K6OVGHO8         2.0         4.0         1.0         1.0         4.0
# A2J0WRZSAAHUAP         3.0         2.0         3.0         4.0         5.0
# A2KX3GMQY9LS9N         2.0         5.0         1.0         2.0         NaN
# A2RGVNP1D6LRTA         5.0         2.0         5.0         5.0         NaN
# A30CP7L9JPBWX          3.0         1.0         3.0         3.0         2.0
# A34IX57PYIKFFF         5.0         1.0         4.0         1.0         2.0
# A35G5VLYZIDBAU         2.0         4.0         1.0         1.0         4.0
# A361YMXSRYL4K4         NaN         3.0         NaN         1.0         4.0
# A36IT4R58E2F10         4.0         5.0         5.0         NaN         NaN
# A38RKP6G5P8J63         5.0         5.0         2.0         2.0         2.0
# A3FYN0SZYWN74          NaN         4.0         4.0         1.0         1.0
# A3NNL2LPM66ZH5         4.0         2.0         5.0         NaN         3.0
# A42VPA76SE1U3          4.0         4.0         2.0         4.0         5.0
# AJCPRB73A2EPV          NaN         3.0         1.0         NaN         3.0
# AMBJQQSRCAOHS          3.0         4.0         4.0         1.0         5.0
# ANLSE84SL6HWI          4.0         5.0         3.0         5.0         4.0
# ARENM677YXZKX          5.0         NaN         1.0         2.0         2.0
# ARMDSTEI0Z7YW          5.0         1.0         1.0         5.0         1.0
# AVFXCA5AW8I7F          1.0         3.0         1.0         4.0         5.0

# %% [markdown]
# Next, we split our data into a training and test set. 18 reviewers went into our training set and 7 of them went into our test set.

# %%
hc_train, hc_test = tts(hc4)

# %%
hc_train.shape
# Out:
# (18, 10)

# %%
hc_test.shape
# Out:
# (7, 10)

# %% [markdown]
# We found that the average rating in our training dataset was 3.17, which means that these healthcare products tended to be perceived as neither exceptional nor poor, or that the high ratings balanced out the poor ratings.

# %%
avg_rating = hc_train.sum(numeric_only=True).sum() / hc_train.count().sum()
avg_rating
# Out:
# 3.108843537414966

# %% [markdown]
# Next, we calculated the RMSE for our training dataset using the overall raw average as the predicted values, and it was 1.37. Below is the user-item matrix with the calculated squared errors.

# %%
hc_train2 = hc_train.copy()
for i in hc_train2.columns.values:
    for j in hc_train2.index.values:
        hc_train2[i][j] = (hc_train[i][j] - avg_rating)**2
hc_train2
# Out:
# product         0077614992  0615208479  0615269990  0615315860  0615406394  \
# user
# A34IX57PYIKFFF         NaN    0.794160    4.447221    0.011847    0.011847
# A2BWNU3Z38JEZ7    1.229534    3.576473    3.576473    1.229534    0.794160
# A1LBXMFXPT2F7Q         NaN         NaN    0.011847         NaN         NaN
# A1P27BGF8NAI29         NaN    0.011847    3.576473    0.794160    4.447221
# ARENM677YXZKX          NaN    4.447221         NaN         NaN    0.011847
# A35G5VLYZIDBAU    1.229534    0.011847    0.011847         NaN    1.229534
# AJCPRB73A2EPV          NaN    4.447221    4.447221    0.011847         NaN
# A12V35OD8T4ZVP    1.229534    1.229534         NaN    0.011847    4.447221
# A30CP7L9JPBWX     3.576473    3.576473    3.576473    0.794160         NaN
# A361YMXSRYL4K4    0.011847    0.794160    4.447221    0.794160         NaN
# ANLSE84SL6HWI     3.576473    0.011847    0.794160    0.794160    0.794160
# A2J0WRZSAAHUAP    1.229534         NaN         NaN         NaN    0.011847
# AVFXCA5AW8I7F     3.576473    1.229534    3.576473    1.229534         NaN
# A2COS3K6OVGHO8         NaN    1.229534         NaN    3.576473    1.229534
# A38RKP6G5P8J63    1.229534    0.011847    3.576473    3.576473    1.229534
# A102TGNH1D915Z    1.229534    0.011847    0.794160    3.576473         NaN
# A3FYN0SZYWN74     0.794160    0.011847    0.794160    0.011847         NaN
# A2RGVNP1D6LRTA    0.011847    1.229534    0.794160    3.576473    1.229534
#
# product         0615836828  0641710577  0641864507  0681504498  0705394638
# user
# A34IX57PYIKFFF    3.576473    4.447221    0.794160    4.447221    1.229534
# A2BWNU3Z38JEZ7    0.011847    0.011847    0.011847    3.576473         NaN
# A1LBXMFXPT2F7Q    3.576473    4.447221    0.794160    0.011847    0.011847
# A1P27BGF8NAI29    1.229534    3.576473    3.576473    3.576473    0.794160
# ARENM677YXZKX     3.576473         NaN    4.447221    1.229534    1.229534
# A35G5VLYZIDBAU    1.229534    0.794160    4.447221    4.447221    0.794160
# AJCPRB73A2EPV          NaN    0.011847    4.447221         NaN    0.011847
# A12V35OD8T4ZVP    0.794160         NaN    0.794160    4.447221    4.447221
# A30CP7L9JPBWX     0.011847    4.447221    0.011847    0.011847    1.229534
# A361YMXSRYL4K4         NaN    0.011847         NaN    4.447221    0.794160
# ANLSE84SL6HWI     0.794160    3.576473    0.011847    3.576473    0.794160
# A2J0WRZSAAHUAP    0.011847    1.229534    0.011847    0.794160    3.576473
# AVFXCA5AW8I7F     4.447221    0.011847    4.447221    0.794160    3.576473
# A2COS3K6OVGHO8    1.229534    0.794160    4.447221    4.447221    0.794160
# A38RKP6G5P8J63    3.576473    3.576473    1.229534    1.229534    1.229534
# A102TGNH1D915Z    3.576473    0.794160    0.011847         NaN    0.011847
# A3FYN0SZYWN74          NaN    0.794160    0.794160    4.447221    4.447221
# A2RGVNP1D6LRTA    3.576473    1.229534    3.576473    3.576473         NaN

# %%
train_rmse = sqrt(hc_train2.sum(numeric_only=True).sum() / hc_train2.count().sum())
train_rmse
# Out:
# 1.3708791146370387

# %% [markdown]
# We also calculated the RMSE for our test dataset and found it to be 1.55. Below is the user-item matrix with the squared errors.

# %%
hc_test2 = hc_test.copy()
for i in hc_test2.columns.values:
    for j in hc_test2.index.values:
        hc_test2[i][j] = (hc_test[i][j] - avg_rating)**2
hc_test2
# Out:
# product         0077614992  0615208479  0615269990  0615315860  0615406394  \
# user
# A42VPA76SE1U3          NaN    4.447221         NaN    4.447221    3.576473
# ARMDSTEI0Z7YW          NaN    0.011847    4.447221    4.447221    0.794160
# A11O3IHGGJBH67    3.576473    0.794160    4.447221    1.229534    3.576473
# A36IT4R58E2F10    0.011847    1.229534    1.229534    4.447221         NaN
# A2KX3GMQY9LS9N    4.447221    3.576473    1.229534    1.229534    0.011847
# A3NNL2LPM66ZH5    4.447221    3.576473         NaN         NaN    3.576473
# AMBJQQSRCAOHS          NaN    3.576473    3.576473    0.794160    0.794160
#
# product         0615836828  0641710577  0641864507  0681504498  0705394638
# user
# A42VPA76SE1U3     0.794160    0.794160    1.229534    0.794160    3.576473
# ARMDSTEI0Z7YW     3.576473    4.447221    4.447221    3.576473    4.447221
# A11O3IHGGJBH67    0.011847    0.794160    0.794160    1.229534    4.447221
# A36IT4R58E2F10    0.794160    3.576473    3.576473         NaN         NaN
# A2KX3GMQY9LS9N    1.229534    3.576473    4.447221    1.229534         NaN
# A3NNL2LPM66ZH5    0.794160    1.229534    3.576473         NaN    0.011847
# AMBJQQSRCAOHS     0.011847    0.794160    0.794160    4.447221    3.576473

# %%
test_rmse = sqrt(hc_test2.sum(numeric_only=True).sum() / hc_test2.count().sum())
test_rmse
# Out:
# 1.552336448432413

# %% [markdown]
# Next, we take a different approach to predict ratings by accounting for the biases in users and items. The user bias is the average rating for a user across all items they rated subtracted by the overall average rating for our user-product matrix. User AJCPRB73A2EPV is the harshest and user ANLSE84SL6HWI is the most lenient in their ratings.

# %%
user_train_bias = hc_train.mean(axis=1) - avg_rating
user_train_bias
# Out:
# user
# A34IX57PYIKFFF   -0.442177
# A2BWNU3Z38JEZ7    0.446712
# A1LBXMFXPT2F7Q    0.057823
# A1P27BGF8NAI29    0.668934
# ARENM677YXZKX    -0.775510
# A35G5VLYZIDBAU   -0.664399
# AJCPRB73A2EPV    -1.108844
# A12V35OD8T4ZVP   -0.858844
# A30CP7L9JPBWX     0.335601
# A361YMXSRYL4K4   -0.251701
# ANLSE84SL6HWI     0.991156
# A2J0WRZSAAHUAP    0.034014
# AVFXCA5AW8I7F     0.002268
# A2COS3K6OVGHO8   -0.483844
# A38RKP6G5P8J63    0.191156
# A102TGNH1D915Z    0.516156
# A3FYN0SZYWN74    -0.108844
# A2RGVNP1D6LRTA    0.557823
# dtype: float64

# %% [markdown]
# We also similarly looked at bias in our healthcare products. Product 0615406394 has the lowest ratings and product 0615315860 has the highest ratings.

# %%
product_train_bias = hc_train.mean(axis=0) - avg_rating
product_train_bias
# Out:
# product
# 0077614992   -0.025510
# 0615208479   -0.233844
# 0615269990    0.462585
# 0615315860    0.605442
# 0615406394   -0.654298
# 0615836828    0.491156
# 0641710577    0.016156
# 0641864507   -0.285314
# 0681504498   -0.358844
# 0705394638   -0.046344
# dtype: float64

# %% [markdown]
# We then calculated the baseline predictions for our user-item matrix using the raw average and corresponding user and product biases where baseline predictor = raw average + user bias + product bias. Below is the user-item matrix with the baseline predictions.

# %%
hc_train_baseline_pred = hc_train.copy()
for i in hc_train_baseline_pred.columns.values:
    for j in hc_train_baseline_pred.index.values:
        hc_train_baseline_pred[i][j] = avg_rating + user_train_bias[j] + product_train_bias[i] 
hc_train_baseline_pred
# Out:
# product         0077614992  0615208479  0615269990  0615315860  0615406394  \
# user
# A34IX57PYIKFFF    2.641156    2.432823    3.129252    3.272109    2.012369
# A2BWNU3Z38JEZ7    3.530045    3.321712    4.018141    4.160998    2.901257
# A1LBXMFXPT2F7Q    3.141156    2.932823    3.629252    3.772109    2.512369
# A1P27BGF8NAI29    3.752268    3.543934    4.240363    4.383220    3.123480
# ARENM677YXZKX     2.307823    2.099490    2.795918    2.938776    1.679035
# A35G5VLYZIDBAU    2.418934    2.210601    2.907029    3.049887    1.790146
# AJCPRB73A2EPV     1.974490    1.766156    2.462585    2.605442    1.345702
# A12V35OD8T4ZVP    2.224490    2.016156    2.712585    2.855442    1.595702
# A30CP7L9JPBWX     3.418934    3.210601    3.907029    4.049887    2.790146
# A361YMXSRYL4K4    2.831633    2.623299    3.319728    3.462585    2.202845
# ANLSE84SL6HWI     4.074490    3.866156    4.562585    4.705442    3.445702
# A2J0WRZSAAHUAP    3.117347    2.909014    3.605442    3.748299    2.488559
# AVFXCA5AW8I7F     3.085601    2.877268    3.573696    3.716553    2.456813
# A2COS3K6OVGHO8    2.599490    2.391156    3.087585    3.230442    1.970702
# A38RKP6G5P8J63    3.274490    3.066156    3.762585    3.905442    2.645702
# A102TGNH1D915Z    3.599490    3.391156    4.087585    4.230442    2.970702
# A3FYN0SZYWN74     2.974490    2.766156    3.462585    3.605442    2.345702
# A2RGVNP1D6LRTA    3.641156    3.432823    4.129252    4.272109    3.012369
#
# product         0615836828  0641710577  0641864507  0681504498  0705394638
# user
# A34IX57PYIKFFF    3.157823    2.682823    2.381353    2.307823    2.620323
# A2BWNU3Z38JEZ7    4.046712    3.571712    3.270241    3.196712    3.509212
# A1LBXMFXPT2F7Q    3.657823    3.182823    2.881353    2.807823    3.120323
# A1P27BGF8NAI29    4.268934    3.793934    3.492464    3.418934    3.731434
# ARENM677YXZKX     2.824490    2.349490    2.048019    1.974490    2.286990
# A35G5VLYZIDBAU    2.935601    2.460601    2.159130    2.085601    2.398101
# AJCPRB73A2EPV     2.491156    2.016156    1.714686    1.641156    1.953656
# A12V35OD8T4ZVP    2.741156    2.266156    1.964686    1.891156    2.203656
# A30CP7L9JPBWX     3.935601    3.460601    3.159130    3.085601    3.398101
# A361YMXSRYL4K4    3.348299    2.873299    2.571829    2.498299    2.810799
# ANLSE84SL6HWI     4.591156    4.116156    3.814686    3.741156    4.053656
# A2J0WRZSAAHUAP    3.634014    3.159014    2.857543    2.784014    3.096514
# AVFXCA5AW8I7F     3.602268    3.127268    2.825797    2.752268    3.064768
# A2COS3K6OVGHO8    3.116156    2.641156    2.339686    2.266156    2.578656
# A38RKP6G5P8J63    3.791156    3.316156    3.014686    2.941156    3.253656
# A102TGNH1D915Z    4.116156    3.641156    3.339686    3.266156    3.578656
# A3FYN0SZYWN74     3.491156    3.016156    2.714686    2.641156    2.953656
# A2RGVNP1D6LRTA    4.157823    3.682823    3.381353    3.307823    3.620323

# %% [markdown]
# Finally, we calculated the RMSE using the baseline predictions that account for bias and we found that it went down to 1.20 compared to 1.37 when we used the raw average as the predictions.

# %%
hc_train3 = hc_train.copy()
for i in hc_train2.columns.values:
    for j in hc_train2.index.values:
        hc_train3[i][j] = (hc_train[i][j] - hc_train_baseline_pred[i][j])**2
hc_train3
# Out:
# product         0077614992  0615208479  0615269990  0615315860  0615406394  \
# user
# A34IX57PYIKFFF         NaN    2.456043    4.533713    0.074043    0.975416
# A2BWNU3Z38JEZ7    2.341039    2.816651    0.964048    4.669911    1.207235
# A1LBXMFXPT2F7Q         NaN         NaN    0.395958         NaN         NaN
# A1P27BGF8NAI29         NaN    0.295864    0.577049    0.146858    4.509166
# ARENM677YXZKX          NaN    1.208878         NaN         NaN    1.744948
# A35G5VLYZIDBAU    0.175506    0.623151    0.008644         NaN    0.044039
# AJCPRB73A2EPV          NaN    0.586996    2.139155    0.155676         NaN
# A12V35OD8T4ZVP    0.050396    0.000261         NaN    0.020897    0.354861
# A30CP7L9JPBWX     2.499769    3.201949    1.194585    0.002489         NaN
# A361YMXSRYL4K4    0.028348    1.895305    5.381137    0.288815         NaN
# ANLSE84SL6HWI     0.856569    0.750227    0.316502    0.497649    0.307246
# A2J0WRZSAAHUAP    1.248464         NaN         NaN         NaN    0.261572
# AVFXCA5AW8I7F     3.664924    0.769598    2.034343    2.946555         NaN
# A2COS3K6OVGHO8         NaN    0.153003         NaN    3.131335    0.000858
# A38RKP6G5P8J63    1.624324    0.004377    1.531196    1.198057    0.416931
# A102TGNH1D915Z    2.558368    0.153003    0.007671    0.592219         NaN
# A3FYN0SZYWN74     1.051671    0.054683    0.288815    0.366560         NaN
# A2RGVNP1D6LRTA    0.411082    2.052982    0.016706    0.529826    1.024890
#
# product         0615836828  0641710577  0641864507  0681504498  0705394638
# user
# A34IX57PYIKFFF    3.393616    2.831894    2.620020    1.710401    0.384801
# A2BWNU3Z38JEZ7    1.095606    0.326855    0.073030    3.251848         NaN
# A1LBXMFXPT2F7Q    1.801439    4.764717    1.251372    0.036932    0.014478
# A1P27BGF8NAI29    5.148063    1.454595    2.272666    2.499769    0.072128
# ARENM677YXZKX     4.732845         NaN    1.098344    0.000651    0.082363
# A35G5VLYZIDBAU    0.875349    2.369750    1.343583    1.178529    2.566081
# AJCPRB73A2EPV          NaN    0.967948    0.510776         NaN    1.094835
# A12V35OD8T4ZVP    1.584687         NaN    4.142504    0.794160    1.448789
# A30CP7L9JPBWX     0.875349    6.054557    0.025322    0.007328    1.954686
# A361YMXSRYL4K4         NaN    0.016053         NaN    2.244901    1.414198
# ANLSE84SL6HWI     0.349466    0.781179    0.663713    1.584687    0.002879
# A2J0WRZSAAHUAP    0.401973    1.343313    0.020294    1.478623    3.623260
# AVFXCA5AW8I7F     6.771797    0.016197    3.333535    1.556836    3.745125
# A2COS3K6OVGHO8    1.245805    1.846456    1.794758    1.603152    2.020217
# A38RKP6G5P8J63    1.461303    2.835329    1.029587    0.885775    1.571655
# A102TGNH1D915Z    0.781179    0.128769    0.115386         NaN    0.334843
# A3FYN0SZYWN74          NaN    0.967948    1.652032    2.693395    3.816774
# A2RGVNP1D6LRTA    0.709262    2.831894    2.620020    2.863463         NaN

# %%
train_baseline_pred_rmse = sqrt(hc_train3.sum(numeric_only=True).sum() / hc_train3.count().sum())
train_baseline_pred_rmse
# Out:
# 1.2016448287544108

# %% [markdown]
# To summarize, the predictions that account for the user and product biases had a RMSE of 1.20 while the simpler raw average predictions had a RMSE of 1.37. So, a recommender system that considers bias performs better in predicting a user's ratings for other products given their rating history. These predicted ratings can be used to recommend additional items to a user so that they enjoy future purchases and continue using Amazon's retail services.
